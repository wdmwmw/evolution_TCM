# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(16,12))
df=pd.read_csv('D:Fig_S16/strength/stability.csv',encoding='gbk')

time=list(df['time'])
y1=list(df['same'])
y2=list(df['top_50'])
y3=list(df['top_60'])
y4=list(df['top_70'])
y5=list(df['top_80'])
y6=list(df['top_90'])
y7=list(df['top_100'])
ax=plt.subplot(221)
ax.plot(time,y1,c='green',marker='^',linestyle='--',linewidth=1,label='top hubs with same number\nof core components')
ax.plot(time,y2,c='red',marker='*',linestyle='--',linewidth=1,label='top 50 hubs')
ax.plot(time,y3,c='blue',marker='x',linestyle='--',linewidth=1,label='top 60 hubs')
ax.plot(time,y4,c='lightgreen',marker='^',linestyle='--',linewidth=1,label='top 70 hubs')
ax.plot(time,y5,c='darkorange',marker='*',linestyle='--',linewidth=1,label='top 80 hubs')
ax.plot(time,y6,c='skyblue',marker='x',linestyle='--',linewidth=1,label='top 90 hubs')
ax.plot(time,y6,c='lightseagreen',marker='x',linestyle='--',linewidth=1,label='top 100 hubs')
ax.set_xlabel('time',fontsize=15)
ax.set_ylabel('stability of hubs',fontsize=15)
ax.set_xticklabels(time, rotation=90,fontsize=15)
ax.set_ylim([-0.05,1.05])
ax.set_yticklabels(['{:.1f}'.format(0.0),
                     '{:.1f}'.format(0.0),
                     '{:.1f}'.format(0.2),
                     '{:.1f}'.format(0.4),
                     '{:.1f}'.format(0.6),
                     '{:.1f}'.format(0.8),
                     '{:.1f}'.format(1.0)], fontsize=15)
ax.text(-4,1.03,'A',fontsize=15)
#plt.xticks([]) 
df=pd.read_csv('D:Fig_S16/degree/stability.csv',encoding='gbk')

time=list(df['time'])
y1=list(df['same'])
y2=list(df['top_50'])
y3=list(df['top_60'])
y4=list(df['top_70'])
y5=list(df['top_80'])
y6=list(df['top_90'])
y7=list(df['top_100'])
ax1=plt.subplot(222)
ax1.plot(time,y1,c='green',marker='^',linestyle='--',linewidth=1,label='top hubs with same number\nof core components')
ax1.plot(time,y2,c='red',marker='*',linestyle='--',linewidth=1,label='top 50 hubs')
ax1.plot(time,y3,c='blue',marker='x',linestyle='--',linewidth=1,label='top 60 hubs')
ax1.plot(time,y4,c='lightgreen',marker='^',linestyle='--',linewidth=1,label='top 70 hubs')
ax1.plot(time,y5,c='darkorange',marker='*',linestyle='--',linewidth=1,label='top 80 hubs')
ax1.plot(time,y6,c='skyblue',marker='x',linestyle='--',linewidth=1,label='top 90 hubs')
ax1.plot(time,y6,c='lightseagreen',marker='x',linestyle='--',linewidth=1,label='top 100 hubs')
ax1.set_xlabel('time',fontsize=15)
ax1.set_ylabel('stability of hubs',fontsize=15)
ax1.set_xticklabels(time, rotation=90,fontsize=15)
ax1.set_ylim([-0.05,1.05])
ax1.set_yticklabels(['{:.1f}'.format(0.0),
                     '{:.1f}'.format(0.0),
                     '{:.1f}'.format(0.2),
                     '{:.1f}'.format(0.4),
                     '{:.1f}'.format(0.6),
                     '{:.1f}'.format(0.8),
                     '{:.1f}'.format(1.0)], fontsize=15)
ax1.text(-4,1.03,'B',fontsize=15)
#plt.xticks([]) 
df1=pd.read_csv('D:Fig_S16/strength/same/compare.csv',encoding='gbk')
df2=pd.read_csv('D:Fig_S16/strength/50/compare.csv',encoding='gbk')
df3=pd.read_csv('D:Fig_S16/strength/60/compare.csv',encoding='gbk')
df4=pd.read_csv('D:Fig_S16/strength/70/compare.csv',encoding='gbk')
df5=pd.read_csv('D:Fig_S16/strength/80/compare.csv',encoding='gbk')
df6=pd.read_csv('D:Fig_S16/strength/90/compare.csv',encoding='gbk')
df7=pd.read_csv('D:Fig_S16/strength/100/compare.csv',encoding='gbk')

time=list(df1['time'])
y1=list(df1['common_core_ratio'])
y2=list(df2['common_core_ratio'])
y3=list(df3['common_core_ratio'])
y4=list(df4['common_core_ratio'])
y5=list(df5['common_core_ratio'])
y6=list(df6['common_core_ratio'])
y7=list(df7['common_core_ratio'])
ax2=plt.subplot(223)
ax2.plot(time,y1,c='green',marker='^',linestyle='--',linewidth=1,label='top hubs with same number\nof core components')
ax2.plot(time,y2,c='red',marker='*',linestyle='--',linewidth=1,label='top 50 hubs')
ax2.plot(time,y3,c='blue',marker='x',linestyle='--',linewidth=1,label='top 60 hubs')
ax2.plot(time,y4,c='lightgreen',marker='^',linestyle='--',linewidth=1,label='top 70 hubs')
ax2.plot(time,y5,c='darkorange',marker='*',linestyle='--',linewidth=1,label='top 80 hubs')
ax2.plot(time,y6,c='skyblue',marker='x',linestyle='--',linewidth=1,label='top 90 hubs')
ax2.plot(time,y6,c='lightseagreen',marker='x',linestyle='--',linewidth=1,label='top 100 hubs')
ax2.set_xlabel('time',fontsize=15)
ax2.set_ylabel('overlapping ratio between\nhubs and core components',fontsize=15)
ax2.set_xticklabels(time, rotation=90,fontsize=15)
ax2.set_ylim([-0.05,1.05])
ax2.set_yticklabels([ '{:.1f}'.format(0.0),
                    '{:.1f}'.format(0.0),
   '{:.1f}'.format(0.2),
                    '{:.1f}'.format(0.4),
                    '{:.1f}'.format(0.6),
                  '{:.1f}'.format(0.8),
                   #'{:.1f}'.format(0.85),
                   #'{:.1f}'.format(0.95),
                   '{:.1f}'.format(1.00),
                  ], fontsize=15)
def to_percent(tmp,position):
    return '%1.0f'%(100*tmp)+'%'
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
ax2.text(-4,1.05,'C',fontsize=15)
df1=pd.read_csv('D:Fig_S16/degree/same/compare.csv',encoding='gbk')
df2=pd.read_csv('D:Fig_S16/degree/50/compare.csv',encoding='gbk')
df3=pd.read_csv('D:Fig_S16/degree/60/compare.csv',encoding='gbk')
df4=pd.read_csv('D:Fig_S16/degree/70/compare.csv',encoding='gbk')
df5=pd.read_csv('D:Fig_S16/degree/80/compare.csv',encoding='gbk')
df6=pd.read_csv('D:Fig_S16/degree/90/compare.csv',encoding='gbk')
df7=pd.read_csv('D:Fig_S16/degree/100/compare.csv',encoding='gbk')

time=list(df1['time'])
y1=list(df1['common_core_ratio'])
y2=list(df2['common_core_ratio'])
y3=list(df3['common_core_ratio'])
y4=list(df4['common_core_ratio'])
y5=list(df5['common_core_ratio'])
y6=list(df6['common_core_ratio'])
y7=list(df7['common_core_ratio'])
ax3=plt.subplot(224)
ax3.plot(time,y1,c='green',marker='^',linestyle='--',linewidth=1,label='top hubs with same number\nof core components')
ax3.plot(time,y2,c='red',marker='*',linestyle='--',linewidth=1,label='top 50 hubs')
ax3.plot(time,y3,c='blue',marker='x',linestyle='--',linewidth=1,label='top 60 hubs')
ax3.plot(time,y4,c='lightgreen',marker='^',linestyle='--',linewidth=1,label='top 70 hubs')
ax3.plot(time,y5,c='darkorange',marker='*',linestyle='--',linewidth=1,label='top 80 hubs')
ax3.plot(time,y6,c='skyblue',marker='x',linestyle='--',linewidth=1,label='top 90 hubs')
ax3.plot(time,y6,c='lightseagreen',marker='x',linestyle='--',linewidth=1,label='top 100 hubs')
ax3.set_xlabel('time',fontsize=15)
ax3.set_ylabel('overlapping ratio between\nhubs and core components',fontsize=15)
ax3.set_xticklabels(time, rotation=90,fontsize=15)
ax3.set_ylim([-0.05,1.05])
ax3.set_yticklabels([ '{:.1f}'.format(0.0),
                    '{:.1f}'.format(0.0),
   '{:.1f}'.format(0.2),
                    '{:.1f}'.format(0.4),
                    '{:.1f}'.format(0.6),
                  '{:.1f}'.format(0.8),
                   #'{:.1f}'.format(0.85),
                   #'{:.1f}'.format(0.95),
                   '{:.1f}'.format(1.00),
                  ], fontsize=15)
def to_percent(tmp,position):
    return '%1.0f'%(100*tmp)+'%'
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
ax3.text(-4,1.05,'D',fontsize=15)
plt.legend(loc='lower center', bbox_to_anchor=(-0.25, -0.73),ncols=4,fontsize=13)
plt.subplots_adjust(wspace=0.25,hspace=0.53)
#plt.savefig('D:data/paper_1/2/3/ratio.TIFF',dpi=300,bbox_inches='tight')
plt.savefig('D:Fig_S16/FigS16.TIFF',dpi=300,bbox_inches='tight')
plt.show()
